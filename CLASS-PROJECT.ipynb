# %% [markdown]
# ## INTRODUCTION
# NAME:OSAMOR MATTHEW IFEANYICHUKWU
# MATRIC NO:21120612573
# Email:matthew.osamor@pau.edu.ng

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PSEUDOCODE
# ##  INPUT number(Y)
# ## PROCESS 17-y
# ## IF Y>17
# ## PRINT 2*Y
# ## ELSE y<17
# ## PRINT y

# %%
##Project1
#develop an algorithm to get the difference between a given number and 17
def diff():
    y= int(input("type number nigger: ")) 
    if y <=17:
        print(17-y)
    else:  
        print(y*2)
        return
diff()

# %% [markdown]
# ## Project 2

# %% [markdown]
# Pictorial Representation
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
